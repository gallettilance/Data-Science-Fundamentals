# %% [markdown]
# # Worksheet 16
#
# Name:  Aaron Zheng
# UID: U00544935
#
# ### Topics
#
# - Support Vector Machines (Non-linear case)
#
# ## Support Vector Machines
#
# Follow along in class to implement the perceptron algorithm and create an animation of the algorithm.

# %% [markdown]
# a) As we saw in class, the form
# $$w^T x + b = 0$$
# while simple, does not expose the inner product `<x_i, x_j>` which we know `w` depends on, having done the math. This is critical to applying the "kernel trick" which allows for learning non-linear decision boundaries. Let's modify the above algorithm to use the form
# $$\sum_i \alpha_i <x_i, x> + b = 0$$

# %%
import numpy as np
from PIL import Image as im
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

TEMPFILE = "temp.png"
CENTERS = [[0, 1], [1, 0]]

epochs = 100
learning_rate = .05
expanding_rate = .99
retracting_rate = 1.1

X, labels = datasets.make_blobs(n_samples=10, centers=CENTERS, cluster_std=0.2, random_state=0)
Y = np.array(list(map(lambda x : -1 if x == 0 else 1, labels.tolist())))

alpha_i = np.zeros((len(X),))
b = 0

def snap(x, alpha_i, b, error):
    # create a mesh to plot in
    h = .01  # step size in the mesh
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    meshData = np.c_[xx.ravel(), yy.ravel()]
    cs = np.array([x for x in 'gb'])
    fig, ax = plt.subplots()
    ax.scatter(X[:,0],X[:,1],color=cs[labels].tolist(), s=50, alpha=0.8)

    if error:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='r',fill=False))
    else:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='y',fill=False))
   
    Z = predict_many(alpha_i, b, meshData)
    Z = np.array([0 if z <=0 else 1 for z in Z]).reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.5, cmap=plt.cm.Paired)
    fig.savefig(TEMPFILE)
    plt.close()
    return im.fromarray(np.asarray(im.open(TEMPFILE)))

def predict_many(alpha_i, b, Z):
    res = []
    for i in range(len(Z)):
        res.append(predict(alpha_i, b, Z[i]))
    return np.array(res)

def predict(alpha_i, b, x):
    wx = 0
    for j in range(len(X)):
        wx += alpha_i[j] * np.dot(X[j], x)
    return wx + b

images = []
for _ in range(epochs):
    # pick a point from X at random
    i = np.random.randint(0, len(X))
    error = False
    x, y = X[i], Y[i]
    ypred = predict(alpha_i, b, x)
    if (ypred > 0 and y > 0) or (ypred < 0 and y < 0):
        # classified correctly
        if ypred < 1 and ypred > -1:
            # in the street / street is too wide
            alpha_i[i] += y * learning_rate
            alpha_i = alpha_i * retracting_rate           
            b += y * learning_rate * retracting_rate
        else:
            # street is too narrow
            alpha_i = alpha_i * expanding_rate
            b *= expanding_rate
    else:
        # misclassified
        error = True 
        alpha_i[i] += y * learning_rate
        alpha_i = alpha_i * expanding_rate
        b += y * learning_rate * expanding_rate
        
    images.append(snap(x, alpha_i, b, error))

images[0].save(
    'svm_dual.gif',
    optimize=False,
    save_all=True,
    append_images=images[1:],
    loop=0,
    duration=100
)

# %% [markdown]
# Write a configurable kernel function to apply in lieu of the dot product. Try it out on a dataset that is not linearly separable.

# %%
def polynomial(x_i, x_j, c, n):
    return (np.dot(x_i, x_j) + c) ** n

# %% [markdown]
# b) Assume we fit an SVM using a polynomial Kernel function and it seems to overfit the data. How would you adjust the tuning parameter `n` of the kernel function?

# %% [markdown]
# I would decrease the tuning parameter n as that would result in a less complex decision boundary which generally tends to overfit less.

# %% [markdown]
# c) Assume we fit an SVM using a RBF Kernel function and it seems to underfit the data. How would you adjust the tuning parameter `sigma` of the kernel function?

# %% [markdown]
# I would increase the tuning parameter sigma as it would result in a more complex decision boundary which generally better fits the data, solving the underfitting issue.

# %% [markdown]
# d) Tune the parameter of a specific Kernel function, to fit an SVM (using your code above) to the following dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("spiral.data")
x, y = data[:, :2], data[:, 2]



plt.scatter(x[:,0], x[:,1], c=y)

# %%
import numpy as np
from PIL import Image as im
import matplotlib.pyplot as plt
import sklearn.datasets as datasets


data = np.loadtxt("spiral.data")
X, Y = data[:, :2], np.where(data[:, 2] == 0, -1, 1)

epochs = 100
learning_rate = .05
expanding_rate = .99
retracting_rate = 1.1

alpha_i = np.zeros(len(X))
b = 0

def snap(X, Y, alpha_i, b, error, epoch):
    h = .01  
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    meshData = np.c_[xx.ravel(), yy.ravel()]
    Z = predict_many(alpha_i, b, meshData)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)

    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Spectral, edgecolors='k')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(f"SVM Decision Surface at Epoch {epoch}")
    plt.show()

def predict_many(alpha_i, b, Z):
    return np.array([predict(alpha_i, b, z) for z in Z])

def rbf_kernel(x_i, x_j, sigma):
    return np.exp(-np.linalg.norm(x_i - x_j)**2 / (2 * sigma**2))

def predict(alpha_i, b, x, kernel_func=rbf_kernel, sigma=1.0):
    return sum(alpha * kernel_func(x_n, x, sigma) for alpha, x_n in zip(alpha_i, X)) + b

sigma = 0.5


for epoch in range(epochs):
    for i in range(len(X)):
        error = False
        x_i, y_i = X[i], Y[i]
        y_pred = predict(alpha_i, b, x_i, sigma=sigma)
        if np.sign(y_pred) != y_i:
            error = True
            alpha_i[i] += learning_rate * y_i
            b += learning_rate * y_i

    snap(X, Y, alpha_i, b, error, epoch)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 61
#      58         alpha_i[i] += learning_rate * y_i
#      59         b += learning_rate * y_i
# ---> 61 snap(X, Y, alpha_i, b, error, epoch)
#
# Cell In[10], line 26, in snap(X, Y, alpha_i, b, error, epoch)
#      22 xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#      23                      np.arange(y_min, y_max, h))
#      25 meshData = np.c_[xx.ravel(), yy.ravel()]
# ---> 26 Z = predict_many(alpha_i, b, meshData)
#      27 Z = Z.reshape(xx.shape)
#      29 plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
#
# Cell In[10], line 40, in predict_many(alpha_i, b, Z)
#      39 def predict_many(alpha_i, b, Z):
# ---> 40     return np.array([predict(alpha_i, b, z) for z in Z])
#
# Cell In[10], line 40, in <listcomp>(.0)
#      39 def predict_many(alpha_i, b, Z):
# ---> 40     return np.array([predict(alpha_i, b, z) for z in Z])
#
# Cell In[10], line 46, in predict(alpha_i, b, x, kernel_func, sigma)
#      45 def predict(alpha_i, b, x, kernel_func=rbf_kernel, sigma=1.0):
# ---> 46     return sum(alpha * kernel_func(x_n, x, sigma) for alpha, x_n in zip(alpha_i, X)) + b
#
# Cell In[10], line 46, in <genexpr>(.0)
#      45 def predict(alpha_i, b, x, kernel_func=rbf_kernel, sigma=1.0):
# ---> 46     return sum(alpha * kernel_func(x_n, x, sigma) for alpha, x_n in zip(alpha_i, X)) + b
#
# Cell In[10], line 43, in rbf_kernel(x_i, x_j, sigma)
#      42 def rbf_kernel(x_i, x_j, sigma):
# ---> 43     return np.exp(-np.linalg.norm(x_i - x_j)**2 / (2 * sigma**2))
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:2512, in norm(x, ord, axis, keepdims)
#    2510 else:
#    2511     sqnorm = x.dot(x)
# -> 2512 ret = sqrt(sqnorm)
#    2513 if keepdims:
#    2514     ret = ret.reshape(ndim*[1])
#
# KeyboardInterrupt:
