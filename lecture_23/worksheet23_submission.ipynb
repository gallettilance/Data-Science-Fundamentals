# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 5s 19ms/step - loss: 0.6584
# Epoch 2/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6561
# Epoch 3/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6545
# Epoch 4/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6533
# Epoch 5/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6521
# Epoch 6/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6510
# Epoch 7/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6500
# Epoch 8/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6489
# Epoch 9/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6480
# Epoch 10/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6472
# Epoch 11/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6463
# Epoch 12/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6456
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(2, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 7ms/step - loss: 0.7525
# Epoch 2/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7492
# Epoch 3/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7469
# Epoch 4/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7450
# Epoch 5/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7432
# Epoch 6/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7415
# Epoch 7/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7399
# Epoch 8/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7385
# Epoch 9/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7371
# Epoch 10/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7356
# Epoch 11/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7341
# Epoch 12/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7328
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(4, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 2s 13ms/step - loss: 0.7525
# Epoch 2/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7500
# Epoch 3/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7482
# Epoch 4/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7467
# Epoch 5/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7453
# Epoch 6/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7441
# Epoch 7/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7429
# Epoch 8/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7417
# Epoch 9/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7405
# Epoch 10/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7396
# Epoch 11/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7384
# Epoch 12/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7375
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(5, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 14ms/step - loss: 0.6987
# Epoch 2/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6960
# Epoch 3/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6941
# Epoch 4/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6928
# Epoch 5/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6913
# Epoch 6/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6901
# Epoch 7/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6889
# Epoch 8/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6878
# Epoch 9/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6867
# Epoch 10/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6858
# Epoch 11/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6846
# Epoch 12/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6837
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(10, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 13ms/step - loss: 0.7521
# Epoch 2/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7423
# Epoch 3/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7358
# Epoch 4/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7306
# Epoch 5/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7257
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7213
# Epoch 7/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7172
# Epoch 8/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7136
# Epoch 9/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7099
# Epoch 10/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7064
# Epoch 11/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7027
# Epoch 12/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6996
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(30, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-92519866a555> in <cell line: 39>()
#      37 plt.show()
#      38
# ---> 39 history = model.fit(X, Y, batch_size=50, epochs=200)
#      40
#      41 # Plot the decision boundary
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(5, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(2, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-38fdedaeaa2f> in <cell line: 39>()
#      37 plt.show()
#      38
# ---> 39 history = model.fit(X, Y, batch_size=50, epochs=200)
#      40
#      41 # Plot the decision boundary
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x : m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
Y = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(5, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(2, activation="sigmoid"))  # 2 output units
model.compile(loss="binary_crossentropy", optimizer='adam')

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)  # Use argmax for 2 output units
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# 3/3 [==============================] - 1s 14ms/step - loss: 0.7049
# Epoch 2/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7038
# Epoch 3/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7026
# Epoch 4/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7015
# Epoch 5/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7003
# Epoch 6/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6992
# Epoch 7/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6982
# Epoch 8/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6971
# Epoch 9/200
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x : m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
Y = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(10, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(2, activation="sigmoid"))  # 2 output units
model.compile(loss="binary_crossentropy", optimizer='adam')

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)  # Use argmax for 2 output units
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# 3/3 [==============================] - 1s 10ms/step - loss: 0.7151
# Epoch 2/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7131
# Epoch 3/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7111
# Epoch 4/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7092
# Epoch 5/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7074
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7057
# Epoch 7/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7041
# Epoch 8/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7025
# Epoch 9/200
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x : m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
Y = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(50, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(2, activation="sigmoid"))  # 2 output units
model.compile(loss="binary_crossentropy", optimizer='adam')

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)  # Use argmax for 2 output units
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# 3/3 [==============================] - 4s 21ms/step - loss: 0.6953
# Epoch 2/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6872
# Epoch 3/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6817
# Epoch 4/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6763
# Epoch 5/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6724
# Epoch 6/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6690
# Epoch 7/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6668
# Epoch 8/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6639
# Epoch 9/200
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmykbgr'])  # Extended to cover all classes

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x : m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
Y_encoded = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(10000, input_dim=2, activation="sigmoid"))  # First layer with 20 units
model.add(layers.Dense(2, activation="sigmoid"))  # Second layer with 5 units
model.compile(loss="categorical_crossentropy", optimizer='adam')  # Corrected loss function for multi-class classification

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

# Make sure data types are float32
X = X.astype(np.float32)
Y_encoded = Y_encoded.astype(np.float32)

history = model.fit(X, Y_encoded, batch_size=50, epochs=200)

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

# Make predictions and plot the decision boundary
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

fig, ax = plt.subplots()
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points with the original Y labels
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# 3/3 [==============================] - 3s 18ms/step - loss: 2.7410
# Epoch 2/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.0210
# Epoch 3/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3734
# Epoch 4/200
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5282
# Epoch 5/200
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1646
# Epoch 6/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6500
# Epoch 7/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7608
# Epoch 8/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7063
# Epoch 9/200
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x : m.cos(4 * x[0]) - x[1] < -.5 or m.cos(4 * x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
Y = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(5, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(2, activation="sigmoid"))  # 2 output units
model.compile(loss="binary_crossentropy", optimizer='adam')

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)  # Use argmax for 2 output units
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[np.argmax(Y, axis=1)].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-59778b3f52c8> in <cell line: 41>()
#      39 plt.show()
#      40
# ---> 41 history = model.fit(X, Y, batch_size=50, epochs=200)
#      42
#      43 # Plot the decision boundary
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ...

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, random
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1, random_state=1)

colors = np.array([x for x in 'bgrcmykbgr'])  # Extended to cover all classes

# CURVE
def generate_curve_data(t):
    X = np.array(list(filter(lambda x: m.cos(4 * x[0]) - x[1] < -0.5 or m.cos(4 * x[0]) - x[1] > 0.5, t)))
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

X, Y = generate_curve_data(t)

# One-hot encoding the labels
encoder = OneHotEncoder(categories='auto', sparse=False)
Y_encoded = encoder.fit_transform(Y.reshape(-1, 1))

# The model
model = keras.models.Sequential()
model.add(layers.Dense(20, input_dim=2, activation="sigmoid"))  # First layer with 20 units
model.add(layers.Dense(5, activation="sigmoid"))  # Second layer with 5 units
model.compile(loss="categorical_crossentropy", optimizer='adam')  # Use categorical crossentropy for multi-class

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)  # Use original Y for coloring

plt.show()

history = model.fit(X, Y_encoded, batch_size=50, epochs=200)  # Use Y_encoded for fitting

# Plot the decision boundary
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.argmax(Z, axis=1)  # Use argmax for output units
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)  # Use original Y for coloring
plt.title("Decision Boundary")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2bb65f7c06e2> in <cell line: 42>()
#      40 plt.show()
#      41
# ---> 42 history = model.fit(X, Y_encoded, batch_size=50, epochs=200)  # Use Y_encoded for fitting
#      43
#      44 # Plot the decision boundary
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
# ...
