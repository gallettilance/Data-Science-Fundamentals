# %% [markdown]
# # Worksheet 15
#
# Name:  Viktoria Zruttova
# UID: U13977544
#
# ### Topics
#
# - Support Vector Machines
#
# ## Support Vector Machines
#
# a) Follow along in class to implement the perceptron algorithm and create an animation of the algorithm.

# %%
import numpy as np
from PIL import Image as im
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

TEMPFILE = "temp.png"
CENTERS = [[0, 1], [1, 0]]

# Dataset
X, labels = datasets.make_blobs(n_samples=10, centers=CENTERS, cluster_std=0.2, random_state=0)
Y = np.array(list(map(lambda x : -1 if x == 0 else 1, labels.tolist())))

# Initializing w and b
w = np.array([1, 1])
b = 0.1

# Perceptron Parameters
epochs = 100
alpha = .05
expanding_rate = .99
retracting_rate = 1.1

def snap(x, w, b, error):
    """
        Plot the street induced by w and b.
        Circle the point x in red if it was
        misclassified or in yellow if it was
        classified correctly.
    """

    xplot = np.linspace(-3, 3)
    cs = np.array([x for x in 'gb'])

    svm = (w[1]/w[0] *xplot - b/w[0])
    left_svm = (1/w[0]) - (w[1]/w[0])
    right_svm = (1/w[0]) - (w[1]/w[0])

    fig, ax = plt.subplots()
    ax.scatter(X[:,0],X[:,1],color=cs[labels].tolist(), s=50, alpha=0.8)
    if error:
        ax.add_patch(plt.Circle((x[0], x[1]), .2, color='r',fill=False))
    else:
        ax.add_patch(plt.Circle((x[0], x[1]), .2, color='y',fill=False))
    ax.plot(xplot, left_svm, 'g--', lw=2)
    ax.plot(xplot, svm, 'r-', lw=2)
    ax.plot(xplot, right_svm, 'b--', lw=2)
    ax.set_xlim(min(X[:, 0]) - 1, max(X[:,0]) + 1)
    ax.set_ylim(min(X[:, 1]) - 1, max(X[:,1]) + 1)
    fig.savefig(TEMPFILE)
    plt.close()

    return im.fromarray(np.asarray(im.open(TEMPFILE)))


images = []
for _ in range(epochs):
    # pick a point from X at random
    i = np.random.randint(0,len(X))
    x, y = X[i], Y[i]
    error = False
    #check if it is classified correctly
    
    y_predict = np.dot(w,x)+b
    if (y < 0 and y_predict < 0) or (y >=0 and y_predict >= 0):
        #correctly classified
        images.append(snap(x, w, b, error))
        continue
    if not (y < 0 and y_predict < 0) or (y >=0 and y_predict >= 0):
        #misclassified
        error = True
        #move in the direction of the misclassified point
        w =w+y*x*alpha
        b+= y * alpha
        #expand the line
        w= w*expanding_rate
        b= b*expanding_rate
        
    else:
        #are u in the street?
        if (y_predict < 1) and (y_predict > -1):
            #yes
            w= w*retracting_rate
            b= b*retracting_rate
        
                    
    images.append(snap(x, w, b, error))

images[0].save(
    'svm.gif',
    optimize=False,
    save_all=True,
    append_images=images[1:],
    loop=0,
    duration=100
)

# %% [markdown]
# b) Consider the following dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

centers = [[0, 1], [1, 0]]
X, _ = datasets.make_blobs(n_samples=10, centers=centers, cluster_std=0.3, random_state=0)
Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])

cs = np.array([x for x in 'bg'])
_, ax = plt.subplots()
ax.scatter(X[:,0],X[:,1],color=cs[Y].tolist(), s=50, alpha=0.8)
ax.set_aspect('equal', adjustable='datalim')
ax.add_patch(plt.Circle((X[0][0], X[0][1]), .1, color='r',fill=False))
ax.add_patch(plt.Circle((X[1][0], X[1][1]), .1, color='r',fill=False))
plt.show()

# %% [markdown]
# if we fit an SVM to the above dataset, moved the points circled in red, and re-fit the SVM, describe how the fit would change depending on how the points are moved.

# %% [markdown]
# Moving the circled points can change where the SVM draws the line between the two groups. If a point moves closer to the line but stays on the same side, the change might be small. But if it crosses the line into the other group, the line will move a lot to catch it. If a point moves away from the line, it might not matter much unless it's really important. Overall, how much it changes depends on how close the points are to the line and how much they matter to the SVM.

# %% [markdown]
# c) If we were to fit an SVM to the above dataset, which points do you think would affect the decision boundary the most? Circle them in red.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

# Generating the dataset
centers = [[0, 1], [1, 0]]
X, _ = datasets.make_blobs(n_samples=10, centers=centers, cluster_std=0.3, random_state=0)
Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])

# Plotting the dataset
cs = np.array([x for x in 'bg'])
_, ax = plt.subplots()
ax.scatter(X[:,0],X[:,1],color=cs[Y].tolist(), s=50, alpha=0.8)
ax.set_aspect('equal', adjustable='datalim')


support_indices = [3, 4, 5, 6, 7]  
for idx in support_indices:
    ax.add_patch(plt.Circle((X[idx][0], X[idx][1]), .1, color='r', fill=False))

plt.show()
